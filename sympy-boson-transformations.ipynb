# %% [markdown]
# # Unitary transformations of boson operators

# %%
from sympy import *
init_printing()

from sympy.physics.quantum import *

# %%
from IPython.display import display_latex
from IPython.display import Latex

def show_first_few_terms(e, n=10):
    if isinstance(e, Add):
        e_args_trunc = e.args[0:n]
        e = Add(*(e_args_trunc))
    
    return Latex("$" + latex(e).replace("dag", "dagger") + r"+ \dots$")

# %%
def recursive_commutator(a, b, n=1):
    return Commutator(a, b) if n == 1 else Commutator(a, recursive_commutator(a, b, n-1))

# %%
def bch_expansion(A, B, N=10):
    """
    Baker–Campbell–Hausdorff formula:
    
    e^{A} B e^{-A} = B + 1/(1!)[A, B] + 1/(2!)[A, [A, B]] + 1/(3!)[A, [A, [A, B]]] + ...
                   = B + Sum_n^N 1/(n!)[A, B]^n
                   
    Truncate the sum at N terms.
    """
    e = B
    for n in range(1, N):
        e += recursive_commutator(A, B, n=n) / factorial(n)
    
    return e

# %%
omega_0, t, alpha = symbols("omega_0, t, alpha")
n = 8

# %%
a = BosonOperator("a")

# %% [markdown]
# ## Transformations with $U = \exp(i \omega_0 a^\dagger a t)$

# %%
A = I * omega_0 * Dagger(a) * a * t

# %% [markdown]
# ### $U a^\dagger a U^\dagger = e^{i \omega_0 a^\dagger a t} a^\dagger a e^{-i \omega_0 a^\dagger a t} = a^\dagger a$

# %%
e = bch_expansion(A, Dagger(a) * a, n).doit()

normal_ordered_form(e)
# Out:
#  †
# a ⋅a

# %% [markdown]
# ### $U a U^\dagger = a e^{-i\omega_0t}$

# %%
e = bch_expansion(A, a, n).doit()

e = normal_ordered_form(expand(e))

e = collect(e, a)

e
# Out:
# ⎛    7  7     6  6       5  5     4  4       3  3     2  2             ⎞
# ⎜ⅈ⋅ω₀ ⋅t    ω₀ ⋅t    ⅈ⋅ω₀ ⋅t    ω₀ ⋅t    ⅈ⋅ω₀ ⋅t    ω₀ ⋅t              ⎟
# ⎜──────── - ────── - ──────── + ────── + ──────── - ────── - ⅈ⋅ω₀⋅t + 1⎟⋅a
# ⎝  5040      720       120        24        6         2                ⎠

# %%
e == (exp(-I * omega_0 * t).series(t, 0, n=n).removeO()) * a
# Out:
# True

# %% [markdown]
# ### $U a^\dagger U^\dagger = a^\dagger e^{i\omega_0t}$

# %%
e = bch_expansion(A, Dagger(a), n).doit()

e = normal_ordered_form(expand(e))

e = collect(e, Dagger(a))

e
# Out:
# ⎛      7  7     6  6       5  5     4  4       3  3     2  2             ⎞
# ⎜  ⅈ⋅ω₀ ⋅t    ω₀ ⋅t    ⅈ⋅ω₀ ⋅t    ω₀ ⋅t    ⅈ⋅ω₀ ⋅t    ω₀ ⋅t              ⎟  †
# ⎜- ──────── - ────── + ──────── + ────── - ──────── - ────── + ⅈ⋅ω₀⋅t + 1⎟⋅a
# ⎝    5040      720       120        24        6         2                ⎠

# %%
e == (exp(I * omega_0 * t).series(t, 0, n=n).removeO()) * Dagger(a)
# Out:
# True

# %% [markdown]
# ## Transformations with $U = D(\alpha) = e^{\alpha a^\dagger - \alpha^* a}$:

# %%
H = Dagger(a) * alpha - conjugate(alpha) * a

# %% [markdown]
# ### $U a U^\dagger = a - \alpha$

# %%
e = bch_expansion(H, a, n).doit()

e
# Out:
#                  ⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †
# ⎛   †   _  ⎞     ⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a
# ⎝α⋅a  - α⋅a⎠⋅a + ─────────────────────────────────────────────────────────────
#
#
#    _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞
#  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞
# ⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _
# - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †
# ⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛
# - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛
# a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛
# a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞
# a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞
# a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _
# ⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛
# ⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛
#   - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _
#   - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛
# ⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞
#   - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛
# - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _
# α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛
# a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †
# ⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛
#  α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞
# ⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞
# ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †
# ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †
# α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †
#  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞
# α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅
# ──────────────────────────────────────────────────────────────────────────────
#                    5040
#
# ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †
# ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †
# α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †
#  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞
#  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _
# ⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _
# ⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _
# ⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †
# ⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛
# - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞
# a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞
# a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞
# ⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛
# ⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞
# a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛
# ⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _
#   - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛
# ⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _
# α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛
# a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _
# α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †
# a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †
#  α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛
#  α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞
# ⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛
# a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   †   _  ⎞⎞ ⎛   †   _  ⎞   ⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _
# ⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠   ⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α
# ──────────────────────── + ───────────────────────────────────────────────────
#
#
#   ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛
# ⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛
#   - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛
# α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _
# α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †
# a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †
#  α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †
#  α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛
#  α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞
# ⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞
# ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †
# a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †
# α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞
# α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅
# ──────────────────────────────────────────────────────────────────────────────
#                    720
#
# ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †
# ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞
# α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †
# ⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞
#  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †
# - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _
# - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †
# ⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛
# - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛
# a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞
# a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _
# ⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞
# ⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞ ⎛   †   _  ⎞   ⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †
# ⎠⋅⎝α⋅a  - α⋅a⎠   ⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a
# ────────────── + ─────────────────────────────────────────────────────────────
#
#
#    _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞
#  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †
# - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _
# - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛
# ⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞
# a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛
# ⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                            120
#
#  †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞
# a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _
# ⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _
# ⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛
# ⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞
#   - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞   ⎛
# - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠   ⎝α⋅
# ──────────────────────────────────────────────────────────────────────── + ───
#
#
#  †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛
# a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞
# a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞
# a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _
# ⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α
# ──────────────────────────────────────────────────────────────────────────────
#   24
#
#   ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛
# ⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛
#   - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# †   _  ⎞   ⎛   †   _  ⎞ ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛
#   - α⋅a⎠   ⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅
# ──────── + ───────────────────────────────────────────────────────────────────
#
#
#  †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞ ⎛⎛   †   _  ⎞
# a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a -
# ──────────────────────────────────────────────────────────────────────────────
#                                             6
#
#   ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞⎞ ⎛   †   _  ⎞
# a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    ⎛   †   _  ⎞ ⎛⎛   †   _  ⎞       ⎛   †   _  ⎞⎞   ⎛⎛   †   _  ⎞       ⎛   †
#    ⎝α⋅a  - α⋅a⎠⋅⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a  - α⋅a⎠⎠ - ⎝⎝α⋅a  - α⋅a⎠⋅a - a⋅⎝α⋅a
#  + ───────────────────────────────────────────────────────────────────────────
#                                                   2
#
#   _  ⎞⎞ ⎛   †   _  ⎞
# - α⋅a⎠⎠⋅⎝α⋅a  - α⋅a⎠         ⎛   †   _  ⎞
# ──────────────────── + a - a⋅⎝α⋅a  - α⋅a⎠

# %%
normal_ordered_form(expand(e))
# Out:
# -α + a

# %% [markdown]
# ### $U a^\dagger U^\dagger = a^\dagger - \alpha^*$

# %%
e = bch_expansion(H, Dagger(a), n).doit()

normal_ordered_form(expand(e))
# Out:
#   _    †
# - α + a

# %% [markdown]
# ### $U a^\dagger a U^\dagger = a^\dagger a - \alpha a^\dagger - \alpha^* a + |\alpha|^2$

# %%
e = bch_expansion(H, Dagger(a) * a, n).doit()

normal_ordered_form(expand(e))
# Out:
#   _      †   _      †
# α⋅α - α⋅a  - α⋅a + a ⋅a

# %% [markdown]
# ## Optomechanical system

# %% [markdown]
# Consider the standard Hamiltonian for an optomechanical syste, including a classical driving signal on the optical mode:
#
# $$
# H = \hbar\omega_a a^\dagger a + \hbar \omega_b b^\dagger b + \hbar g a^\dagger a (b + b^\dagger) + (A e^{-i\omega_d t} + A^* e^{i\omega_d t})(a + a^\dagger)
# $$

# %%
n = 6
omega_a, omega_b, omega_d, g, A, Hsym = symbols("omega_a, omega_b, omega_d, g, A, H")

# %%
a, b = BosonOperator("a"), BosonOperator("b")

# %%
H = omega_a * Dagger(a) * a + omega_b * Dagger(b) * b + g * Dagger(a) * a * (b + Dagger(b)) \
    + (A * exp(-I * omega_d * t) + conjugate(A) * exp(I * omega_d * t)) * (a + Dagger(a))

Eq(Hsym, H)
# Out:
#        †   ⎛ †    ⎞       †          †     ⎛   -ⅈ⋅ω_d⋅t    ⅈ⋅ω_d⋅t _⎞ ⎛ †    ⎞
# H = g⋅a ⋅a⋅⎝b  + b⎠ + ωₐ⋅a ⋅a + ω_b⋅b ⋅b + ⎝A⋅ℯ         + ℯ       ⋅A⎠⋅⎝a  + a⎠

# %% [markdown]
# ### Linearized interaction

# %% [markdown]
# First we apply the unitary transformation $U = e^{i \omega_d a^\dagger a t} = e^A$:

# %%
def hamiltonian_transformation(H, UH, n):
    """
    Apply an unitary basis transformation to the Hamiltonian H:
    
    H = U H U^\dagger -i U d/dt(U^\dagger)
    
    U = exp(UH)
    
    """
    return - I * exp(UH) * diff(exp(-UH), t) + \
                normal_ordered_form(expand(bch_expansion(UH, H, n).doit(independent=True)), independent=True)

# %%
UH = I * Dagger(a) * a * omega_d * t

# %%
H1 = hamiltonian_transformation(H, UH, n)

#show_first_few_terms(H1, n=5)
H1
# Out:
#        5  5  -ⅈ⋅ω_d⋅t  †          5  5  -ⅈ⋅ω_d⋅t          4  4  -ⅈ⋅ω_d⋅t  †
# ⅈ⋅A⋅ω_d ⋅t ⋅ℯ        ⋅a    ⅈ⋅A⋅ω_d ⋅t ⋅ℯ        ⋅a   A⋅ω_d ⋅t ⋅ℯ        ⋅a
# ──────────────────────── - ─────────────────────── + ────────────────────── +
#           120                        120                       24
#
#      4  4  -ⅈ⋅ω_d⋅t            3  3  -ⅈ⋅ω_d⋅t  †          3  3  -ⅈ⋅ω_d⋅t
# A⋅ω_d ⋅t ⋅ℯ        ⋅a   ⅈ⋅A⋅ω_d ⋅t ⋅ℯ        ⋅a    ⅈ⋅A⋅ω_d ⋅t ⋅ℯ        ⋅a   A
# ───────────────────── - ──────────────────────── + ─────────────────────── - ─
#           24                       6                          6
#
#     2  2  -ⅈ⋅ω_d⋅t  †        2  2  -ⅈ⋅ω_d⋅t
# ⋅ω_d ⋅t ⋅ℯ        ⋅a    A⋅ω_d ⋅t ⋅ℯ        ⋅a              -ⅈ⋅ω_d⋅t  †
# ───────────────────── - ───────────────────── + ⅈ⋅A⋅ω_d⋅t⋅ℯ        ⋅a  - ⅈ⋅A⋅ω
#          2                        2
#
#
#       -ⅈ⋅ω_d⋅t        -ⅈ⋅ω_d⋅t  †      -ⅈ⋅ω_d⋅t        †          †  †
# _d⋅t⋅ℯ        ⋅a + A⋅ℯ        ⋅a  + A⋅ℯ        ⋅a + g⋅a ⋅a⋅b + g⋅a ⋅b ⋅a + ωₐ⋅
#
#
#                        5  5  ⅈ⋅ω_d⋅t _  †        5  5  ⅈ⋅ω_d⋅t _        4  4
#  †          †     ⅈ⋅ω_d ⋅t ⋅ℯ       ⋅A⋅a    ⅈ⋅ω_d ⋅t ⋅ℯ       ⋅A⋅a   ω_d ⋅t ⋅ℯ
# a ⋅a + ω_b⋅b ⋅b + ─────────────────────── - ────────────────────── + ─────────
#                             120                      120
#
# ⅈ⋅ω_d⋅t _  †      4  4  ⅈ⋅ω_d⋅t _          3  3  ⅈ⋅ω_d⋅t _  †        3  3  ⅈ⋅ω
#        ⋅A⋅a    ω_d ⋅t ⋅ℯ       ⋅A⋅a   ⅈ⋅ω_d ⋅t ⋅ℯ       ⋅A⋅a    ⅈ⋅ω_d ⋅t ⋅ℯ
# ──────────── + ──────────────────── - ─────────────────────── + ──────────────
#  24                     24                       6                        6
#
# _d⋅t _        2  2  ⅈ⋅ω_d⋅t _  †      2  2  ⅈ⋅ω_d⋅t _
#     ⋅A⋅a   ω_d ⋅t ⋅ℯ       ⋅A⋅a    ω_d ⋅t ⋅ℯ       ⋅A⋅a            ⅈ⋅ω_d⋅t _
# ──────── - ───────────────────── - ──────────────────── + ⅈ⋅ω_d⋅t⋅ℯ       ⋅A⋅a
#                      2                      2
#
#
# †            ⅈ⋅ω_d⋅t _          †      ⅈ⋅ω_d⋅t _  †    ⅈ⋅ω_d⋅t _
#   - ⅈ⋅ω_d⋅t⋅ℯ       ⋅A⋅a - ω_d⋅a ⋅a + ℯ       ⋅A⋅a  + ℯ       ⋅A⋅a

# %%
collect(H1, [exp(-I * omega_d * t) * A * a,
             exp(-I * omega_d * t) * A * Dagger(a),
             exp(I * omega_d * t) * conjugate(A) * a,
             exp(I * omega_d * t) * conjugate(A) * Dagger(a)])
# Out:
#   ⎛       5  5      4  4        3  3      2  2              ⎞
#   ⎜  ⅈ⋅ω_d ⋅t    ω_d ⋅t    ⅈ⋅ω_d ⋅t    ω_d ⋅t               ⎟  -ⅈ⋅ω_d⋅t
# A⋅⎜- ───────── + ─────── + ───────── - ─────── - ⅈ⋅ω_d⋅t + 1⎟⋅ℯ        ⋅a + A⋅
#   ⎝     120         24         6          2                 ⎠
#
# ⎛     5  5      4  4        3  3      2  2              ⎞
# ⎜ⅈ⋅ω_d ⋅t    ω_d ⋅t    ⅈ⋅ω_d ⋅t    ω_d ⋅t               ⎟  -ⅈ⋅ω_d⋅t  †      †
# ⎜───────── + ─────── - ───────── - ─────── + ⅈ⋅ω_d⋅t + 1⎟⋅ℯ        ⋅a  + g⋅a ⋅
# ⎝   120         24         6          2                 ⎠
#
#                                                   ⎛       5  5      4  4
#          †  †         †          †          †     ⎜  ⅈ⋅ω_d ⋅t    ω_d ⋅t    ⅈ⋅ω
# a⋅b + g⋅a ⋅b ⋅a + ωₐ⋅a ⋅a + ω_b⋅b ⋅b - ω_d⋅a ⋅a + ⎜- ───────── + ─────── + ───
#                                                   ⎝     120         24
#
#   3  3      2  2              ⎞                ⎛     5  5      4  4        3
# _d ⋅t    ω_d ⋅t               ⎟  ⅈ⋅ω_d⋅t _     ⎜ⅈ⋅ω_d ⋅t    ω_d ⋅t    ⅈ⋅ω_d ⋅t
# ────── - ─────── - ⅈ⋅ω_d⋅t + 1⎟⋅ℯ       ⋅A⋅a + ⎜───────── + ─────── - ────────
#  6          2                 ⎠                ⎝   120         24         6
#
# 3      2  2              ⎞
#     ω_d ⋅t               ⎟  ⅈ⋅ω_d⋅t _  †
# ─ - ─────── + ⅈ⋅ω_d⋅t + 1⎟⋅ℯ       ⋅A⋅a
#        2                 ⎠

# %% [markdown]
# We can now performa rotating-wave approximation (RWA) by eliminating all terms that rotate with frequencies

# %%
H2 = expand(H1.series(t, n=n).removeO())

show_first_few_terms(H2, n=10)
# Out:
# $- \frac{4 i}{15} A \omega_{d}^{5} t^{5} {a} + \frac{2 A}{3} \omega_{d}^{4} t^{4} {a} + \frac{4 i}{3} A \omega_{d}^{3} t^{3} {a} - 2 A \omega_{d}^{2} t^{2} {a} + A {{a}^\dagger} + A {a} + g {{a}^\dagger} {{b}^\dagger} {a} + \omega_{b} {{b}^\dagger} {b} + \frac{2 \omega_{d}^{4}}{3} t^{4} \overline{A} {{a}^\dagger} - 2 \omega_{d}^{2} t^{2} \overline{A} {{a}^\dagger}+ \dots$

# %%
H3 = H2.subs(t, 0)

H3
# Out:
#    †            †          †  †         †          †          †     _  †   _
# A⋅a  + A⋅a + g⋅a ⋅a⋅b + g⋅a ⋅b ⋅a + ωₐ⋅a ⋅a + ω_b⋅b ⋅b - ω_d⋅a ⋅a + A⋅a  + A⋅a

# %% [markdown]
# ## Versions

# %%
# %reload_ext version_information

# %version_information sympy
# Out:
# Software versions
# Python 3.4.0 (default, Apr 11 2014, 13:05:11) [GCC 4.8.2]
# IPython 3.0.0-dev
# OS posix [linux]
# sympy 0.7.4.1-git
#
# Wed Jun 04 15:43:49 2014 JST
